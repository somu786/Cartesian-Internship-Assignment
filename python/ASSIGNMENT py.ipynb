# %%
#TODO
#prints each word in reverse.  
#prints Top 2 occurring words in sorted order. The words that have occurred most of the time.


# importing mode for finding max repeating element
from statistics import mode

# getting input 
# while getting input, I just change it to lowercase and by using split function it'll became list(seprated by whitespaces)
s = input().lower().split(' ')

# reverse the list by using reverse()
s.reverse()

# To achive the exact output. I just capitalize the first letter in our reversed list
s[0] = s[0].capitalize()

print()
print('Printing word in reverse:')
print()

# Displaying the list without [] and ,
print(*s) 
print()

print('Occurrence of words:')
print()  


# by using mode(), we can get max occur element list and with count() we can get frequency
# Displaying Top occurancing word with count
print(mode(s),':',str(s.count(mode(s))),'times')


# to remove all the occurance of Most occured element by using list comprehension:
temp = [i for i in s if i != mode(s)]


## above list comprehenssion is detailed below by using general for loops,
'''temp=[]
for i in s:
    if i != mode(s):   #if the element is not the most occured element then it will append to the list temp
        temp.append(i)''' 


# Displaying 2nd most occuring word with count
print(mode(temp),':',str(s.count(mode(temp))),'times')


# Done


# Input / Output

# Input: This declaration represents a political commitment among declaration partners to advance a positive vision for the Internet in this era of a united europe

#Output :
#Printing word in reverse:

#Europe united a of era this in internet the for vision positive a advance to partners declaration among commitment political a represents declaration this

#Occurrence of words:

#a : 3 times
#this : 2 times















# Here I'm using list comprehension to split. list comprehension approach is little faster 

#temp = [word for sub in s for word in sub.split()]

## above list comprehenssion is detailed below by using general for loops,
#temp=[]#for sub in s:
#    for word in sub.split():
#        temp.append(word)'''
# Out:
# This declaration represents a political commitment among declaration partners to advance a positive vision for the Internet in this era of a united europe
#
# Printing word in reverse:
#
# Europe united a of era this in internet the for vision positive a advance to partners declaration among commitment political a represents declaration this
#
# Occurrence of words:
#
# a : 3 times
# this : 2 times
